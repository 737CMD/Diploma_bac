# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
class airfoil:
    def __init__(self, r_forw, up_coord, down_coord):
# Out:
#   Cell In[3], line 1
#     class airfoil():
#                     ^
# _IncompleteInputError: incomplete input
